# %% [markdown]
# # Tutorials Utilized for this Notebook:
#
#
# *   Word2Vec with ingredients: https://www.kaggle.com/code/ccorbi/word2vec-with-ingredients/notebook
# *   Gensim Word2Vec tutorial: https://www.kaggle.com/code/pierremegret/gensim-word2vec-tutorial
#
# **Code that has been taken from these tutorials has been labeled in the cells**

# %%
from gensim.models import word2vec
import numpy as np
import pandas as pd
from time import time
import re
import json

# %%
# method to do top-n words calculations
def topWordsCalculations(model_to_use, words):
  for word in words:
    top10 = model_to_use.wv.most_similar(word)
    print('word=', word)
    print('output:', top10)
    print('top-1 average:', top10[0][1])
    print('top-5 average:', sum([w[1] for w in top10[0:5]])/5)
    print('top-10 average:', sum([w[1] for w in top10])/10)
    print('\n')

# %% [markdown]
# # Data Loading / Processing

# %%
path_to_data = '/content/recipes.json'

# code taken from:  https://www.kaggle.com/code/ccorbi/word2vec-with-ingredients/notebook (word2vec with ingredients)
train_recipes = json.load(open(path_to_data,'r'))

raw_ingredients = list()

for recipe in train_recipes:
    for ingredient in recipe[u'ingredients']:
        raw_ingredients.append(ingredient.strip())

raw_ingredients
# Out:
# ['romaine lettuce',
#  'black olives',
#  'grape tomatoes',
#  'garlic',
#  'pepper',
#  'purple onion',
#  'seasoning',
#  'garbanzo beans',
#  'feta cheese crumbles',
#  'plain flour',
#  'ground pepper',
#  'salt',
#  'tomatoes',
#  'ground black pepper',
#  'thyme',
#  'eggs',
#  'green tomatoes',
#  'yellow corn meal',
#  'milk',
#  'vegetable oil',
#  'eggs',
#  'pepper',
#  'salt',
#  'mayonaise',
#  'cooking oil',
#  'green chilies',
#  'grilled chicken breasts',
#  'garlic powder',
#  'yellow onion',
#  'soy sauce',
#  'butter',
#  'chicken livers',
#  'water',
#  'vegetable oil',
#  'wheat',
#  'salt',
#  'black pepper',
#  'shallots',
#  'cornflour',
#  'cayenne pepper',
#  'onions',
#  'garlic paste',
#  'milk',
#  'butter',
#  'salt',
#  'lemon juice',
#  'water',
#  'chili powder',
#  'passata',
#  'oil',
#  'ground cumin',
#  'boneless chicken skinless thigh',
#  'garam masala',
#  'double cream',
#  'natural yogurt',
#  'bay leaf',
#  'plain flour',
#  'sugar',
#  'butter',
#  'eggs',
#  'fresh ginger root',
#  'salt',
#  'ground cinnamon',
#  'milk',
#  'vanilla extract',
#  'ground ginger',
#  'powdered sugar',
#  'baking powder',
#  'olive oil',
#  'salt',
#  'medium shrimp',
#  'pepper',
#  'garlic',
#  'chopped cilantro',
#  'jalapeno chilies',
#  'flat leaf parsley',
#  'skirt steak',
#  'white vinegar',
#  'sea salt',
#  'bay leaf',
#  'chorizo sausage',
#  'sugar',
#  'pistachio nuts',
#  'white almond bark',
#  'flour',
#  'vanilla extract',
#  'olive oil',
#  'almond extract',
#  'eggs',
#  'baking powder',
#  'dried cranberries',
#  'olive oil',
#  'purple onion',
#  'fresh pineapple',
#  'pork',
#  'poblano peppers',
#  'corn tortillas',
#  'cheddar cheese',
#  'ground black pepper',
#  'salt',
#  'iceberg lettuce',
#  'lime',
#  'jalapeno chilies',
#  'chopped cilantro fresh',
#  'chopped tomatoes',
#  'fresh basil',
#  'garlic',
#  'extra-virgin olive oil',
#  'kosher salt',
#  'flat leaf parsley',
#  'pimentos',
#  'sweet pepper',
#  'dried oregano',
#  'olive oil',
#  'garlic',
#  'sharp cheddar cheese',
#  'pepper',
#  'swiss cheese',
#  'provolone cheese',
#  'canola oil',
#  'mushrooms',
#  'black olives',
#  'sausages',
#  'low sodium soy sauce',
#  'fresh ginger',
#  'dry mustard',
#  'green beans',
#  'white pepper',
#  'sesame oil',
#  'scallions',
#  'canola oil',
#  'sugar',
#  'Shaoxing wine',
#  'garlic',
#  'ground turkey',
#  'water',
#  'crushed red pepper flakes',
#  'corn starch',
#  'Italian parsley leaves',
#  'walnuts',
#  'hot red pepper flakes',
#  'extra-virgin olive oil',
#  'fresh lemon juice',
#  'trout fillet',
#  'garlic cloves',
#  'chipotle chile',
#  'fine sea salt',
#  'flat leaf parsley',
#  'ground cinnamon',
#  'fresh cilantro',
#  'chili powder',
#  'ground coriander',
#  'kosher salt',
#  'ground black pepper',
#  'garlic',
#  'plum tomatoes',
#  'avocado',
#  'lime juice',
#  'flank steak',
#  'salt',
#  'ground cumin',
#  'black pepper',
#  'olive oil',
#  'crushed red pepper flakes',
#  'onions',
#  'fresh parmesan cheese',
#  'butter',
#  'all-purpose flour',
#  'fat free less sodium chicken broth',
#  'chopped fresh chives',
#  'gruyere cheese',
#  'ground black pepper',
#  'bacon slices',
#  'gnocchi',
#  'fat free milk',
#  'cooking spray',
#  'salt',
#  'tumeric',
#  'vegetable stock',
#  'tomatoes',
#  'garam masala',
#  'naan',
#  'red lentils',
#  'red chili peppers',
#  'onions',
#  'spinach',
#  'sweet potatoes',
#  'greek yogurt',
#  'lemon curd',
#  'confectioners sugar',
#  'raspberries',
#  'italian seasoning',
#  'broiler-fryer chicken',
#  'mayonaise',
#  'zesty italian dressing',
#  'sugar',
#  'hot chili',
#  'asian fish sauce',
#  'lime juice',
#  'soy sauce',
#  'vegetable oil',
#  'red bell pepper',
#  'chicken broth',
#  'yellow squash',
#  'garlic chili sauce',
#  'sliced green onions',
#  'broccolini',
#  'salt',
#  'fresh lime juice',
#  'cooked rice',
#  'chicken breasts',
#  'corn starch',
#  'pork loin',
#  'roasted peanuts',
#  'chopped cilantro fresh',
#  'hoisin sauce',
#  'creamy peanut butter',
#  'chopped fresh mint',
#  'thai basil',
#  'rice',
#  'medium shrimp',
#  'water',
#  'rice noodles',
#  'beansprouts',
#  'roma tomatoes',
#  'kosher salt',
#  'purple onion',
#  'jalapeno chilies',
#  'lime',
#  'chopped cilantro',
#  'low-fat mayonnaise',
#  'pepper',
#  'salt',
#  'baking potatoes',
#  'eggs',
#  'spicy brown mustard',
#  'sesame seeds',
#  'red pepper',
#  'yellow peppers',
#  'water',
#  'extra firm tofu',
#  'broccoli',
#  'soy sauce',
#  'orange bell pepper',
#  'arrowroot powder',
#  'fresh ginger',
#  'sesame oil',
#  'red curry paste',
#  'marinara sauce',
#  'flat leaf parsley',
#  'olive oil',
#  'linguine',
#  'capers',
#  'crushed red pepper flakes',
#  'olives',
#  'lemon zest',
#  'garlic',
#  'sugar',
#  'lo mein noodles',
#  'salt',
#  'chicken broth',
#  'light soy sauce',
#  'flank steak',
#  'beansprouts',
#  'dried black mushrooms',
#  'pepper',
#  'chives',
#  'oyster sauce',
#  'dark soy sauce',
#  'peanuts',
#  'sesame oil',
#  'cabbage',
#  'herbs',
#  'lemon juice',
#  'fresh tomatoes',
#  'paprika',
#  'mango',
#  'stock',
#  'chile pepper',
#  'onions',
#  'red chili peppers',
#  'oil',
#  'ground black pepper',
#  'butter',
#  'sliced mushrooms',
#  'sherry',
#  'salt',
#  'grated parmesan cheese',
#  'heavy cream',
#  'spaghetti',
#  'chicken broth',
#  'cooked chicken',
#  'all-purpose flour',
#  'green bell pepper',
#  'egg roll wrappers',
#  'sweet and sour sauce',
#  'corn starch',
#  'molasses',
#  'vegetable oil',
#  'oil',
#  'soy sauce',
#  'shredded cabbage',
#  'garlic',
#  'onions',
#  'fresh ginger root',
#  'ground pork',
#  'carrots',
#  'flour tortillas',
#  'cheese',
#  'breakfast sausages',
#  'large eggs',
#  'yellow corn meal',
#  'boiling water',
#  'butter',
#  'fresh parmesan cheese',
#  'sea salt',
#  'chicken broth',
#  'chicken breasts',
#  'hot sauce',
#  'red bell pepper',
#  'potatoes',
#  'bacon',
#  'garlic cloves',
#  'fresh parsley',
#  'andouille sausage',
#  'cajun seasoning',
#  'peanut oil',
#  'celery',
#  'ground red pepper',
#  'all-purpose flour',
#  'shrimp',
#  'onions',
#  'chili powder',
#  'crushed red pepper flakes',
#  'garlic powder',
#  'sea salt',
#  'ground cumin',
#  'onion powder',
#  'dried oregano',
#  'ground black pepper',
#  'paprika',
#  'eggs',
#  'shallots',
#  'firm tofu',
#  'beansprouts',
#  'turnips',
#  'palm sugar',
#  'vegetable oil',
#  'garlic cloves',
#  'sliced chicken',
#  'fish sauce',
#  'lime wedges',
#  'roasted peanuts',
#  'green papaya',
#  'chile powder',
#  'ground black pepper',
#  'tamarind paste',
#  'chinese chives',
#  'olive oil',
#  'onions',
#  'crushed garlic',
#  'dried oregano',
#  'green onions',
#  'white sugar',
#  'dried basil',
#  'diced tomatoes',
#  'olive oil',
#  'diced tomatoes',
#  'Johnsonville Andouille Dinner Sausage',
#  'parsley',
#  'shrimp',
#  'jambalaya rice mix',
#  'worcestershire sauce',
#  'hot pepper sauce',
#  'creole seasoning',
#  'olive oil',
#  'bread slices',
#  'great northern beans',
#  'garlic cloves',
#  'pepper',
#  'shrimp',
#  'sage leaves',
#  'salt',
#  'chicken broth',
#  'cooking oil',
#  'chinese five-spice powder',
#  'ground black pepper',
#  'salt',
#  'sugar',
#  'crushed garlic',
#  'chicken thighs',
#  'soy sauce',
#  'star anise',
#  'green onions',
#  'cream cheese',
#  'shredded cheddar cheese',
#  'cayenne pepper',
#  'chili powder',
#  'garlic cloves',
#  'black-eyed peas',
#  'tortilla chips',
#  'collard greens',
#  'extra-virgin olive oil',
#  'ham hock',
#  'chicken stock',
#  'apple cider',
#  'freshly ground pepper',
#  'chile powder',
#  'bay leaves',
#  'salt',
#  'rib',
#  'light brown sugar',
#  'large garlic cloves',
#  'cayenne pepper',
#  'onions',
#  'Oscar Mayer Deli Fresh Smoked Ham',
#  'hoagie rolls',
#  'salami',
#  'giardiniera',
#  'mozzarella cheese',
#  'pepperoni',
#  'butter',
#  'italian seasoning',
#  'ice cubes',
#  'club soda',
#  'white rum',
#  'lime',
#  'turbinado',
#  'cooked chicken',
#  'enchilada sauce',
#  'sliced green onions',
#  'picante sauce',
#  'green pepper',
#  'corn tortillas',
#  'canned black beans',
#  'shredded lettuce',
#  'sour cream',
#  'shredded cheddar cheese',
#  'garlic cloves',
#  'canola oil',
#  'salmon fillets',
#  'shallots',
#  'cumin seed',
#  'fresh cilantro',
#  'salt',
#  'curry powder',
#  'vegetable oil',
#  'serrano chile',
#  'fresh ginger',
#  'sauce',
#  'tomatoes',
#  'chicken breast halves',
#  'chopped cilantro fresh',
#  'white vinegar',
#  'jalapeno chilies',
#  'salt',
#  'black pepper',
#  'vegetable oil',
#  'avocado',
#  'lettuce leaves',
#  'chopped onion',
#  'eggs',
#  'mandarin oranges',
#  'water',
#  'orange liqueur',
#  'yellow cake mix',
#  'frosting',
#  'vegetable oil',
#  'white sugar',
#  'sugar',
#  'salt',
#  'fennel bulb',
#  'water',
#  'lemon olive oil',
#  'grapefruit juice',
#  'sugar',
#  'all-purpose flour',
#  'vegetable oil',
#  'white cornmeal',
#  'baking powder',
#  'onions',
#  'bacon drippings',
#  'buttermilk',
#  'butter',
#  'crab boil',
#  'garlic',
#  'old bay seasoning',
#  'cream cheese',
#  'crawfish',
#  'salt',
#  'mayonaise',
#  'white sugar',
#  'ground black pepper',
#  'salt',
#  'white vinegar',
#  'lemon juice',
#  'sirloin',
#  'mirin',
#  'yellow onion',
#  'low sodium soy sauce',
#  'water',
#  'corn oil',
#  'sugar',
#  'green onions',
#  'glass noodles',
#  'sake',
#  'shiitake',
#  'napa cabbage',
#  'large eggs',
#  'whipping cream',
#  'chicken broth',
#  'ground red pepper',
#  'extra sharp cheddar cheese',
#  'quickcooking grits',
#  'hot sauce',
#  'ground black pepper',
#  'worcestershire sauce',
#  'monterey jack',
#  'fresh basil',
#  'bay leaves',
#  'crushed red pepper',
#  'mussels',
#  'olive oil',
#  'basil',
#  'garlic cloves',
#  'black pepper',
#  'dry white wine',
#  'salt',
#  'tomatoes',
#  'finely chopped onion',
#  'linguine',
#  'flat leaf parsley',
#  'sugar',
#  'large eggs',
#  'all-purpose flour',
#  'baking soda',
#  'buttermilk',
#  'honey',
#  'corn oil',
#  'yellow corn meal',
#  'unsalted butter',
#  'salt',
#  'lemon',
#  'pesto',
#  'salmon fillets',
#  'white wine',
#  'bread crumbs',
#  'unsalted butter',
#  'onion powder',
#  'curry',
#  'low sodium beef broth',
#  'pickapeppa sauce',
#  'curry powder',
#  'bay leaves',
#  'garlic',
#  'cayenne pepper',
#  'cold water',
#  'pepper',
#  'large eggs',
#  'extra-virgin olive oil',
#  'yellow onion',
#  'allspice',
#  'white vinegar',
#  'kosher salt',
#  'fresh thyme',
#  'worcestershire sauce',
#  'all-purpose flour',
#  'ground beef',
#  'melted butter',
#  'matcha green tea powder',
#  'white sugar',
#  'milk',
#  'all-purpose flour',
#  'eggs',
#  'salt',
#  'baking powder',
#  'chopped walnuts',
#  'coarse salt',
#  'fenugreek',
#  'urad dal',
#  'potatoes',
#  'white rice',
#  'vegetable oil',
#  'pizza crust',
#  'plum tomatoes',
#  'pesto',
#  'part-skim mozzarella cheese',
#  'cooking spray',
#  'salt',
#  'black pepper',
#  'yukon gold potatoes',
#  'low-fat sour cream',
#  'leeks',
#  'olive oil',
#  '1% low-fat milk',
#  'sugar',
#  'chicken thighs',
#  'cooking oil',
#  'fish sauce',
#  'garlic',
#  'black pepper',
#  'lemongrass',
#  'large garlic cloves',
#  'rice',
#  'unsweetened coconut milk',
#  'fresh ginger',
#  'peanut sauce',
#  'spareribs',
#  'sesame oil',
#  'tamari soy sauce',
#  'golden brown sugar',
#  'dry sherry',
#  'boiling water',
#  'chicken legs',
#  'chile pepper',
#  'ghee',
#  'tomato paste',
#  'fresh ginger root',
#  'garlic',
#  'chopped cilantro fresh',
#  'water',
#  'vegetable oil',
#  'onions',
#  'tomatoes',
#  'garam masala',
#  'cumin seed',
#  'ground turmeric',
#  'stock',
#  'curry powder',
#  'cracked black pepper',
#  'minced beef',
#  'onions',
#  'plain flour',
#  'bread crumbs',
#  'butter',
#  'garlic',
#  'celery',
#  'cold water',
#  'tumeric',
#  'dried thyme',
#  'ginger',
#  'oil',
#  'tomatoes',
#  'water',
#  'paprika',
#  'salt',
#  'chillies',
#  'crushed tomatoes',
#  'garlic',
#  'fresh rosemary',
#  'ground black pepper',
#  'onions',
#  'olive oil',
#  'boneless pork loin',
#  'kosher salt',
#  'pappardelle',
#  'extra firm tofu',
#  'coconut milk',
#  'fresh basil',
#  'red curry paste',
#  'eggplant',
#  'red bell pepper',
#  'vegetable oil',
#  'onions',
#  'jasmine rice',
#  'garlic',
#  'scallions',
#  'sugar',
#  'shiitake',
#  'Gochujang base',
#  'beansprouts',
#  'top round steak',
#  'sesame seeds',
#  'rice vinegar',
#  'carrots',
#  'soy sauce',
#  'sesame oil',
#  'Taiwanese bok choy',
#  'vanilla',
#  'milk',
#  'large egg yolks',
#  'sugar',
#  'corn starch',
#  'orange juice concentrate',
#  'pumpkin purée',
#  'marshmallow creme',
#  'toasted pecans',
#  'maple syrup',
#  'ground cinnamon',
#  'gingersnap',
#  'ground nutmeg',
#  'cream cheese',
#  'black pepper',
#  'white sugar',
#  'white vinegar',
#  'salt',
#  'bacon',
#  'brown sugar',
#  'green beans',
#  'large eggs',
#  'serrano ham',
#  'manchego cheese',
#  'butter',
#  'dijon mustard',
#  'sourdough',
#  'membrillo',
#  'burger buns',
#  'fresh cilantro',
#  'chili powder',
#  'garlic cloves',
#  'panko breadcrumbs',
#  'chickpea flour',
#  'pepper',
#  'Sriracha',
#  'chickpeas',
#  'carrots',
#  'ground flaxseed',
#  'soy sauce',
#  'olive oil',
#  'salt',
#  'lemon juice',
#  'greens',
#  'spinach',
#  'curry powder',
#  'tahini',
#  'scallions',
#  'onions',
#  'ground cumin',
#  'ground cloves',
#  'whole nutmegs',
#  'ground ginger',
#  'ground coriander',
#  'ground cinnamon',
#  'ground cardamom',
#  'ground black pepper',
#  'ground cumin',
#  'tomatoes',
#  'red pepper',
#  'olive oil',
#  'Italian bread',
#  'balsamic vinegar',
#  'onions',
#  'fresh basil',
#  'garlic',
#  'sausage casings',
#  'ground black pepper',
#  'garlic',
#  'honey',
#  'grated parmesan cheese',
#  'shredded mozzarella cheese',
#  'kosher salt',
#  'roasted red peppers',
#  'penne pasta',
#  'olive oil',
#  'crushed red pepper flakes',
#  'tumeric',
#  'olive oil',
#  'lemon',
#  'saffron',
#  'tomato paste',
#  'pepper',
#  'flour',
#  'chickpeas',
#  'chicken stock',
#  'warm water',
#  'fresh ginger',
#  'salt',
#  'tomatoes',
#  'fresh cilantro',
#  'shallots',
#  'fresh parsley',
#  'ground pepper',
#  'paprika',
#  'ground cardamom',
#  'chopped cilantro fresh',
#  'preserved lemon',
#  'harissa',
#  'salt',
#  'couscous',
#  'tomato paste',
#  'cayenne',
#  'garlic',
#  'fat skimmed chicken broth',
#  'ground turmeric',
#  'pitted kalamata olives',
#  'diced tomatoes',
#  'fat',
#  'onions',
#  'sweetened condensed milk',
#  'ice',
#  'espresso',
#  'top round steak',
#  'vegetable oil',
#  'shiitake',
#  'soy sauce',
#  'fresh asparagus',
#  'green onions',
#  'avocado',
#  'chopped cilantro fresh',
#  'jalapeno chilies',
#  'finely chopped onion',
#  'plum tomatoes',
#  'green chilies',
#  'pecans',
#  'golden brown sugar',
#  'crumbled blue cheese',
#  'garlic cloves',
#  'chuck',
#  'hamburger buns',
#  'hot pepper sauce',
#  'creole seasoning',
#  'onions',
#  'mayonaise',
#  'ground black pepper',
#  'salt',
#  'okra pods',
#  'andouille sausage',
#  'olive oil',
#  'watercress',
#  'fresh lemon juice',
#  'sugar',
#  'vanilla',
#  'eggs',
#  'self rising flour',
#  'confectioners sugar',
#  'milk',
#  'softened butter',
#  'food colouring',
#  'butter',
#  'Madeira',
#  'foie gras',
#  'demi-glace',
#  'sherry vinegar',
#  'whipping cream',
#  'white bread',
#  'Fuyu persimmons',
#  'salt',
#  'egg bread',
#  'watercress',
#  'fenugreek leaves',
#  'olive oil',
#  'garlic',
#  'black mustard seeds',
#  'ground cumin',
#  'amchur',
#  'lime wedges',
#  'scallions',
#  'coriander',
#  'sugar',
#  'fingerling potatoes',
#  'green chilies',
#  'chopped cilantro',
#  'tumeric',
#  'fresh ginger root',
#  'salt',
#  'ramps',
#  'black peppercorns',
#  'cinnamon sticks',
#  'cardamom pods',
#  'cumin seed',
#  'coriander seeds',
#  'spinach',
#  'asiago',
#  'whole wheat pasta',
#  'olive oil',
#  'sweet onion',
#  'garlic',
#  'grape tomatoes',
#  'mushrooms',
#  'chestnuts',
#  'granulated sugar',
#  'whole milk ricotta cheese',
#  'coffee ice cream',
#  'large eggs',
#  'mascarpone',
#  'rum',
#  'powdered sugar',
#  'semisweet chocolate',
#  'chestnut flour',
#  'baby spinach leaves',
#  'naan',
#  'unsalted butter',
#  'chopped garlic',
#  'water',
#  'large shrimp',
#  'tomatoes',
#  'salt',
#  'water',
#  'barley',
#  'cooked ham',
#  'red bell pepper',
#  'seasoning',
#  'potatoes',
#  'olive oil',
#  'onions',
#  'eggs',
#  'bacon',
#  'salt',
#  'starchy potatoes',
#  'grated nutmeg',
#  'flour',
#  'ground black pepper',
#  'all-purpose flour',
#  'milk',
#  'buttermilk',
#  'sirloin tip roast',
#  'coarse salt',
#  'steak',
#  'vegetable oil',
#  'cayenne pepper',
#  'granulated sugar',
#  'all-purpose flour',
#  'vegetable shortening',
#  'baking powder',
#  'milk',
#  'salt',
#  'ground pork',
#  'finely chopped fresh parsley',
#  'onions',
#  'salt',
#  'vinegar',
#  'caul fat',
#  'ground cinnamon',
#  'whole milk',
#  'golden brown sugar',
#  'heavy whipping cream',
#  'kahlúa',
#  'corn starch',
#  'instant espresso powder',
#  'boneless chicken skinless thigh',
#  'lime',
#  'epazote',
#  'bay leaf',
#  'lime juice',
#  'radishes',
#  'salt',
#  'oregano',
#  'white onion',
#  'hominy',
#  'garlic',
#  'chopped cilantro',
#  'avocado',
#  'fresh cilantro',
#  'tomatillos',
#  'pepitas',
#  'canola oil',
#  'catfish fillets',
#  'ground black pepper',
#  'salt',
#  'dried thyme',
#  'ground red pepper',
#  'peanut oil',
#  'yellow corn meal',
#  'large eggs',
#  'all-purpose flour',
#  'garlic powder',
#  'buttermilk',
#  'olive oil',
#  'sea salt',
#  'coconut milk',
#  'water',
#  'garam masala',
#  'ground coriander',
#  'basmati rice',
#  'cauliflower',
#  'fresh ginger',
#  'green chilies',
#  'onions',
#  'fresh cilantro',
#  'potatoes',
#  'scallions',
#  'cumin',
#  'olive oil',
#  'olives',
#  'salt',
#  'blood orange',
#  'freshly ground pepper',
#  'fennel bulb',
#  'balsamic vinegar',
#  'low salt chicken broth',
#  'dijon mustard',
#  'corn starch',
#  'dried basil',
#  'garlic cloves',
#  'white wine vinegar',
#  'tomato sauce',
#  'shredded carrots',
#  'spinach',
#  'part-skim mozzarella cheese',
#  'italian seasoning',
#  'english muffins, split and toasted',
#  'chopped onion',
#  'vegetable oil cooking spray',
#  'chopped green bell pepper',
#  'prawns',
#  'rice flour',
#  'seasoning salt',
#  'salt',
#  'vegetable oil',
#  'club soda',
#  ...]

# %%
import collections
word_counts = collections.Counter(raw_ingredients)
word_counts.most_common()
# Out:
# [('salt', 18049),
#  ('onions', 7972),
#  ('olive oil', 7972),
#  ('water', 7457),
#  ('garlic', 7380),
#  ('sugar', 6434),
#  ('garlic cloves', 6237),
#  ('butter', 4848),
#  ('ground black pepper', 4785),
#  ('all-purpose flour', 4632),
#  ('pepper', 4438),
#  ('vegetable oil', 4385),
#  ('eggs', 3388),
#  ('soy sauce', 3296),
#  ('kosher salt', 3113),
#  ('green onions', 3078),
#  ('tomatoes', 3058),
#  ('large eggs', 2948),
#  ('carrots', 2814),
#  ('unsalted butter', 2782),
#  ('ground cumin', 2747),
#  ('extra-virgin olive oil', 2747),
#  ('black pepper', 2627),
#  ('milk', 2263),
#  ('chili powder', 2036),
#  ('oil', 1970),
#  ('red bell pepper', 1939),
#  ('purple onion', 1896),
#  ('scallions', 1891),
#  ('grated parmesan cheese', 1886),
#  ('sesame oil', 1773),
#  ('corn starch', 1757),
#  ('ginger', 1755),
#  ('baking powder', 1738),
#  ('jalapeno chilies', 1730),
#  ('dried oregano', 1707),
#  ('chopped cilantro fresh', 1698),
#  ('fresh lemon juice', 1679),
#  ('diced tomatoes', 1624),
#  ('fresh parsley', 1604),
#  ('minced garlic', 1583),
#  ('chicken broth', 1554),
#  ('sour cream', 1539),
#  ('cayenne pepper', 1523),
#  ('fresh ginger', 1503),
#  ('brown sugar', 1503),
#  ('cooking spray', 1490),
#  ('shallots', 1477),
#  ('garlic powder', 1442),
#  ('lime', 1439),
#  ('lemon juice', 1395),
#  ('fresh lime juice', 1368),
#  ('flour', 1348),
#  ('honey', 1299),
#  ('vanilla extract', 1298),
#  ('paprika', 1287),
#  ('chopped onion', 1251),
#  ('fish sauce', 1247),
#  ('ground cinnamon', 1231),
#  ('avocado', 1229),
#  ('canola oil', 1223),
#  ('dry white wine', 1218),
#  ('lemon', 1218),
#  ('rice vinegar', 1204),
#  ('yellow onion', 1184),
#  ('green bell pepper', 1180),
#  ('cilantro leaves', 1160),
#  ('tomato paste', 1158),
#  ('heavy cream', 1146),
#  ('cilantro', 1142),
#  ('fresh basil', 1137),
#  ('boneless skinless chicken breasts', 1111),
#  ('flat leaf parsley', 1094),
#  ('white sugar', 1093),
#  ('lime juice', 1072),
#  ('chicken stock', 1039),
#  ('bay leaves', 1036),
#  ('potatoes', 1018),
#  ('chicken', 982),
#  ('corn tortillas', 965),
#  ('salsa', 963),
#  ('cumin', 953),
#  ('freshly ground pepper', 949),
#  ('ground turmeric', 949),
#  ('baking soda', 942),
#  ('sea salt', 940),
#  ('cumin seed', 935),
#  ('garam masala', 925),
#  ('shrimp', 912),
#  ('black beans', 896),
#  ('zucchini', 892),
#  ('ground beef', 878),
#  ('large garlic cloves', 873),
#  ('dried thyme', 873),
#  ('flour tortillas', 865),
#  ('tomato sauce', 865),
#  ('buttermilk', 863),
#  ('plum tomatoes', 858),
#  ('coconut milk', 854),
#  ('granulated sugar', 849),
#  ('fresh cilantro', 841),
#  ('bay leaf', 839),
#  ('celery', 837),
#  ('crushed red pepper', 825),
#  ('chopped cilantro', 796),
#  ('chicken breasts', 793),
#  ('mayonaise', 781),
#  ('shredded cheddar cheese', 769),
#  ('green chilies', 768),
#  ('ground coriander', 768),
#  ('cucumber', 768),
#  ('whole milk', 764),
#  ('red wine vinegar', 752),
#  ('tumeric', 738),
#  ('cinnamon', 696),
#  ('curry powder', 694),
#  ('worcestershire sauce', 688),
#  ('white onion', 684),
#  ('ground ginger', 678),
#  ('sesame seeds', 676),
#  ('hot sauce', 674),
#  ('red pepper flakes', 669),
#  ('cinnamon sticks', 646),
#  ('red chili peppers', 644),
#  ('bacon', 620),
#  ('whipping cream', 619),
#  ('boneless skinless chicken breast halves', 618),
#  ('peanut oil', 610),
#  ('ground nutmeg', 605),
#  ('clove', 600),
#  ('parmesan cheese', 591),
#  ('dried basil', 585),
#  ('peeled fresh ginger', 582),
#  ('mushrooms', 578),
#  ('coarse salt', 578),
#  ('warm water', 577),
#  ('large egg yolks', 575),
#  ('balsamic vinegar', 574),
#  ('celery ribs', 567),
#  ('cream cheese', 562),
#  ('white vinegar', 554),
#  ('egg yolks', 542),
#  ('capers', 541),
#  ('ground red pepper', 538),
#  ('onion powder', 528),
#  ('dijon mustard', 513),
#  ('rice', 509),
#  ('cold water', 506),
#  ('crushed red pepper flakes', 505),
#  ('mirin', 503),
#  ('fresh basil leaves', 502),
#  ('powdered sugar', 501),
#  ('eggplant', 501),
#  ('large egg whites', 485),
#  ('cooking oil', 483),
#  ('lime wedges', 482),
#  ('shredded mozzarella cheese', 475),
#  ('fat free less sodium chicken broth', 473),
#  ('ground pork', 473),
#  ('sliced green onions', 472),
#  ('cayenne', 470),
#  ('mozzarella cheese', 467),
#  ('medium shrimp', 461),
#  ('raisins', 460),
#  ('red pepper', 459),
#  ('sauce', 458),
#  ('coriander', 458),
#  ('finely chopped onion', 457),
#  ('sweet potatoes', 455),
#  ('oyster sauce', 455),
#  ('beansprouts', 454),
#  ('crushed tomatoes', 453),
#  ('black peppercorns', 453),
#  ('egg whites', 453),
#  ('cheese', 447),
#  ('fresh rosemary', 442),
#  ('oregano', 440),
#  ('white pepper', 439),
#  ('cherry tomatoes', 436),
#  ('leeks', 435),
#  ('ketchup', 432),
#  ('hoisin sauce', 429),
#  ('chopped celery', 426),
#  ('low sodium soy sauce', 425),
#  ('cheddar cheese', 424),
#  ('light brown sugar', 422),
#  ('cabbage', 416),
#  ('fresh mint', 416),
#  ('large shrimp', 414),
#  ('vegetable broth', 409),
#  ('cracked black pepper', 408),
#  ('spring onions', 407),
#  ('peanuts', 406),
#  ('chickpeas', 402),
#  ('confectioners sugar', 395),
#  ('italian seasoning', 395),
#  ('coriander seeds', 395),
#  ('fresh oregano', 394),
#  ('lean ground beef', 388),
#  ('cooked rice', 387),
#  ('bell pepper', 387),
#  ('ground pepper', 385),
#  ('low salt chicken broth', 385),
#  ('frozen peas', 383),
#  ('beef broth', 381),
#  ('active dry yeast', 377),
#  ('cajun seasoning', 376),
#  ('chopped fresh thyme', 375),
#  ('green pepper', 373),
#  ('ground cloves', 371),
#  ('cornmeal', 368),
#  ('white wine', 367),
#  ('spinach', 366),
#  ('lemongrass', 364),
#  ('ground allspice', 364),
#  ('plain yogurt', 364),
#  ('thyme', 361),
#  ('feta cheese crumbles', 358),
#  ('hot water', 356),
#  ('orange', 355),
#  ('toasted sesame oil', 355),
#  ('long-grain rice', 353),
#  ('parmigiano reggiano cheese', 353),
#  ('white wine vinegar', 352),
#  ('fennel seeds', 352),
#  ('ricotta cheese', 352),
#  ('boiling water', 350),
#  ('pinenuts', 348),
#  ('ground white pepper', 348),
#  ('cider vinegar', 348),
#  ('light soy sauce', 347),
#  ('parsley', 345),
#  ('sake', 345),
#  ('fresh thyme', 345),
#  ('chopped garlic', 345),
#  ('smoked paprika', 345),
#  ('boneless chicken skinless thigh', 343),
#  ('spaghetti', 342),
#  ('grated lemon zest', 342),
#  ('yellow corn meal', 341),
#  ('green beans', 341),
#  ('chile pepper', 340),
#  ('low sodium chicken broth', 339),
#  ('fresh ginger root', 338),
#  ('orange juice', 338),
#  ('half & half', 337),
#  ('chicken thighs', 336),
#  ('sweet onion', 336),
#  ('chopped parsley', 333),
#  ('shiitake', 331),
#  ('corn', 329),
#  ('basmati rice', 326),
#  ('tomatillos', 322),
#  ('pasta', 321),
#  ('chiles', 321),
#  ('dark brown sugar', 319),
#  ('chopped fresh mint', 317),
#  ('vinegar', 316),
#  ('shredded Monterey Jack cheese', 314),
#  ('mustard seeds', 313),
#  ('dark soy sauce', 312),
#  ('vanilla', 311),
#  ('dry red wine', 309),
#  ('ghee', 307),
#  ('hot pepper sauce', 306),
#  ('bread crumbs', 306),
#  ('tortilla chips', 302),
#  ('green chile', 302),
#  ('pork', 300),
#  ('serrano chile', 299),
#  ('chopped tomatoes', 298),
#  ('Sriracha', 298),
#  ('cooked chicken', 296),
#  ('enchilada sauce', 295),
#  ('toasted sesame seeds', 294),
#  ('arborio rice', 292),
#  ('yellow bell pepper', 291),
#  ('dry bread crumbs', 287),
#  ('fresh parmesan cheese', 286),
#  ('fine sea salt', 285),
#  ('fresh coriander', 285),
#  ('prosciutto', 284),
#  ('garlic paste', 282),
#  ('basil', 282),
#  ('radishes', 282),
#  ('chopped pecans', 282),
#  ('corn kernels', 280),
#  ('juice', 280),
#  ('saffron threads', 277),
#  ('long grain white rice', 277),
#  ('creole seasoning', 276),
#  ('melted butter', 276),
#  ('beef', 273),
#  ('fresh mushrooms', 272),
#  ('sweetened condensed milk', 271),
#  ('taco seasoning', 271),
#  ('romaine lettuce', 270),
#  ('baguette', 270),
#  ('mango', 268),
#  ('chopped green bell pepper', 268),
#  ('feta cheese', 268),
#  ('okra', 268),
#  ('apple cider vinegar', 268),
#  ('andouille sausage', 267),
#  ('basil leaves', 267),
#  ('unsweetened cocoa powder', 266),
#  ('pasta sauce', 266),
#  ('russet potatoes', 266),
#  ('Shaoxing wine', 264),
#  ('rice noodles', 263),
#  ('mint leaves', 263),
#  ('peaches', 263),
#  ('vegetable oil cooking spray', 260),
#  ('star anise', 259),
#  ('flank steak', 258),
#  ('cream', 258),
#  ('baby spinach', 257),
#  ('dry sherry', 256),
#  ('chinese five-spice powder', 253),
#  ('refried beans', 250),
#  ('lemon zest', 249),
#  ('linguine', 248),
#  ('white rice', 248),
#  ('yoghurt', 247),
#  ('coriander powder', 246),
#  ('sliced mushrooms', 244),
#  ('fresh dill', 243),
#  ('diced onions', 242),
#  ('golden raisins', 240),
#  ('garlic salt', 240),
#  ('roasted red peppers', 239),
#  ('ground cardamom', 237),
#  ('nutmeg', 237),
#  ('monterey jack', 235),
#  ('grated nutmeg', 234),
#  ('greek yogurt', 233),
#  ('asparagus', 230),
#  ('fresh spinach', 230),
#  ('black olives', 229),
#  ('marinara sauce', 229),
#  ('red wine', 229),
#  ('shortening', 229),
#  ('grape tomatoes', 228),
#  ('pork tenderloin', 228),
#  ('chopped fresh chives', 227),
#  ('roma tomatoes', 227),
#  ('part-skim mozzarella cheese', 227),
#  ('napa cabbage', 226),
#  ('noodles', 225),
#  ('lemon wedge', 225),
#  ('bananas', 224),
#  ('thai chile', 223),
#  ('ham', 222),
#  ('tortillas', 222),
#  ('cauliflower', 221),
#  ('coconut oil', 221),
#  ('rice wine', 221),
#  ('broccoli', 220),
#  ('margarine', 220),
#  ('red chili powder', 220),
#  ('strawberries', 219),
#  ('curry leaves', 219),
#  ('yukon gold potatoes', 218),
#  ('cashew nuts', 218),
#  ('tomato purée', 217),
#  ('heavy whipping cream', 216),
#  ('salt and ground black pepper', 215),
#  ('cilantro sprigs', 215),
#  ('bacon slices', 212),
#  ('green peas', 212),
#  ('lasagna noodles', 209),
#  ('thyme sprigs', 209),
#  ('fresh orange juice', 209),
#  ('evaporated milk', 208),
#  ('green cabbage', 208),
#  ('baking potatoes', 207),
#  ('firm tofu', 207),
#  ('chives', 206),
#  ('saffron', 206),
#  ('frozen chopped spinach', 206),
#  ('fennel bulb', 205),
#  ('red potato', 205),
#  ('pitted kalamata olives', 204),
#  ('cannellini beans', 203),
#  ('beer', 202),
#  ('brown rice', 202),
#  ('dark sesame oil', 201),
#  ('bourbon whiskey', 199),
#  ('minced ginger', 198),
#  ('vegetables', 197),
#  ('black-eyed peas', 196),
#  ('kalamata', 196),
#  ('water chestnuts', 195),
#  ('almonds', 194),
#  ('1% low-fat milk', 193),
#  ('self rising flour', 193),
#  ('chipotles in adobo', 193),
#  ('bread flour', 193),
#  ('peas', 193),
#  ('vegetable stock', 192),
#  ('french bread', 192),
#  ('unsweetened coconut milk', 191),
#  ('fresh thyme leaves', 190),
#  ('broccoli florets', 190),
#  ('lettuce leaves', 189),
#  ('couscous', 189),
#  ('minced onion', 189),
#  ('anchovy fillets', 189),
#  ('english cucumber', 189),
#  ('chili', 187),
#  ('sliced almonds', 187),
#  ('sausages', 185),
#  ('guacamole', 185),
#  ('grits', 184),
#  ('Tabasco Pepper Sauce', 184),
#  ('snow peas', 183),
#  ('reduced sodium chicken broth', 183),
#  ('lettuce', 183),
#  ('taco seasoning mix', 181),
#  ('grated lemon peel', 181),
#  ('cake flour', 179),
#  ('whole wheat flour', 179),
#  ('all purpose unbleached flour', 179),
#  ('thai basil', 178),
#  ('penne pasta', 178),
#  ('coconut', 178),
#  ('arugula', 177),
#  ('pancetta', 177),
#  ('green olives', 177),
#  ('shredded lettuce', 175),
#  ('mussels', 175),
#  ('frozen corn', 175),
#  ('bread', 175),
#  ('stewed tomatoes', 175),
#  ('Mexican cheese blend', 174),
#  ('butternut squash', 174),
#  ('almond extract', 173),
#  ('dried rosemary', 173),
#  ('hot red pepper flakes', 171),
#  ('spices', 171),
#  ('pinto beans', 171),
#  ('bread crumb fresh', 170),
#  ('goat cheese', 169),
#  ('dried parsley', 169),
#  ('pure vanilla extract', 169),
#  ('brandy', 169),
#  ('ground turkey', 168),
#  ('collard greens', 167),
#  ('slivered almonds', 167),
#  ('shredded sharp cheddar cheese', 167),
#  ('vanilla beans', 167),
#  ('provolone cheese', 165),
#  ('apples', 165),
#  ('iceberg lettuce', 164),
#  ('semisweet chocolate', 164),
#  ('ice water', 164),
#  ('button mushrooms', 163),
#  ('mint', 163),
#  ('sliced black olives', 161),
#  ('sun-dried tomatoes', 161),
#  ('sherry vinegar', 160),
#  ('beef stock', 160),
#  ('salmon fillets', 159),
#  ('fettucine', 159),
#  ('cream of tartar', 159),
#  ('kidney beans', 159),
#  ('light corn syrup', 159),
#  ('asian fish sauce', 158),
#  ('chili flakes', 158),
#  ('wonton wrappers', 158),
#  ('lard', 157),
#  ('pecorino romano cheese', 157),
#  ('reduced sodium soy sauce', 157),
#  ('shredded cheese', 157),
#  ('kale', 157),
#  ('roasted peanuts', 156),
#  ('shredded carrots', 156),
#  ('light coconut milk', 156),
#  ('olives', 155),
#  ('poblano chiles', 155),
#  ('plain flour', 154),
#  ('sharp cheddar cheese', 154),
#  ('cardamom pods', 154),
#  ('dry mustard', 152),
#  ('chicken breast halves', 152),
#  ('jasmine rice', 152),
#  ('orange zest', 152),
#  ('chipotle chile', 150),
#  ('daikon', 150),
#  ('mascarpone', 149),
#  ('grated orange', 149),
#  ('garbanzo beans', 148),
#  ('fresh tomatoes', 148),
#  ('polenta', 148),
#  ('chili sauce', 147),
#  ('boneless chicken breast', 146),
#  ('cooked white rice', 145),
#  ('crème fraîche', 145),
#  ('panko breadcrumbs', 144),
#  ('pecans', 144),
#  ('peppercorns', 144),
#  ('cream cheese, soften', 143),
#  ('ancho chile pepper', 143),
#  ('Gochujang base', 142),
#  ('fresh tarragon', 142),
#  ('szechwan peppercorns', 142),
#  ('queso fresco', 141),
#  ('bittersweet chocolate', 140),
#  ('parsley sprigs', 140),
#  ('ground cayenne pepper', 139),
#  ('smoked sausage', 139),
#  ('cotija', 139),
#  ('vegetable shortening', 138),
#  ('cremini mushrooms', 138),
#  ('seasoning', 137),
#  ('extra firm tofu', 137),
#  ('lime zest', 137),
#  ('italian sausage', 137),
#  ('bamboo shoots', 137),
#  ('meat', 137),
#  ('ground lamb', 136),
#  ('tofu', 136),
#  ('artichoke hearts', 135),
#  ('salsa verde', 135),
#  ('pork shoulder', 135),
#  ('pimentos', 134),
#  ('fat free milk', 134),
#  ('sweet paprika', 134),
#  ('red cabbage', 134),
#  ('chicken wings', 133),
#  ('tequila', 133),
#  ('kaffir lime leaves', 133),
#  ('non-fat sour cream', 133),
#  ('dried apricot', 133),
#  ('fresh parsley leaves', 132),
#  ('seasoning salt', 131),
#  ('chinese rice wine', 131),
#  ('mint sprigs', 131),
#  ('garlic chili sauce', 130),
#  ('ice cubes', 130),
#  ('white bread', 130),
#  ('rice flour', 130),
#  ('caster sugar', 130),
#  ('seeds', 130),
#  ('allspice', 129),
#  ('chopped walnuts', 128),
#  ('dashi', 128),
#  ('whole peeled tomatoes', 127),
#  ('Thai red curry paste', 127),
#  ('chili pepper', 126),
#  ('barbecue sauce', 126),
#  ('dry yeast', 126),
#  ('Italian parsley leaves', 125),
#  ('part-skim ricotta cheese', 125),
#  ('dried shiitake mushrooms', 124),
#  ('pork belly', 124),
#  ('frozen corn kernels', 124),
#  ('chopped fresh sage', 123),
#  ('ginger root', 123),
#  ('red curry paste', 122),
#  ('palm sugar', 122),
#  ('chili paste', 122),
#  ('peanut butter', 122),
#  ('corn oil', 121),
#  ('chillies', 121),
#  ('marsala wine', 121),
#  ('chile powder', 120),
#  ('pineapple', 120),
#  ('poblano peppers', 119),
#  ('granny smith apples', 119),
#  ('gingerroot', 119),
#  ('ginger paste', 119),
#  ('bok choy', 119),
#  ('crawfish', 118),
#  ('pesto', 118),
#  ('Italian bread', 118),
#  ('jack cheese', 118),
#  ('chicken legs', 117),
#  ('lump crab meat', 117),
#  ('greek style plain yogurt', 117),
#  ('pizza doughs', 117),
#  ('yellow squash', 116),
#  ('quinoa', 116),
#  ('dark rum', 116),
#  ('vidalia onion', 115),
#  ('pork sausages', 115),
#  ('walnuts', 114),
#  ('sage leaves', 114),
#  ('sea scallops', 114),
#  ('turnips', 113),
#  ('fresh chives', 113),
#  ('penne', 113),
#  ('black mustard seeds', 112),
#  ('kimchi', 112),
#  ('sweet chili sauce', 112),
#  ('creamy peanut butter', 111),
#  ('shredded cabbage', 111),
#  ('ice', 111),
#  ('cooked chicken breasts', 111),
#  ('red lentils', 110),
#  ('maple syrup', 110),
#  ('paneer', 110),
#  ('catfish fillets', 109),
#  ('chili oil', 109),
#  ('yeast', 109),
#  ('green tomatoes', 108),
#  ('sausage casings', 108),
#  ('unflavored gelatin', 108),
#  ('Thai fish sauce', 108),
#  ('mustard', 108),
#  ('rosemary sprigs', 108),
#  ('crushed garlic', 107),
#  ('fontina cheese', 107),
#  ('rosemary', 107),
#  ('molasses', 106),
#  ('frozen pastry puff sheets', 106),
#  ('curry paste', 106),
#  ('whole kernel corn, drain', 106),
#  ('cardamom', 106),
#  ('romano cheese', 106),
#  ('diced green chilies', 106),
#  ('beets', 106),
#  ('ricotta', 105),
#  ('dough', 105),
#  ('freshly grated parmesan', 105),
#  ('reduced-fat sour cream', 105),
#  ('watercress', 104),
#  ('hard-boiled egg', 104),
#  ('serrano peppers', 104),
#  ('sugar pea', 104),
#  ('cornflour', 103),
#  ('chorizo sausage', 103),
#  ('baby spinach leaves', 103),
#  ('swiss chard', 103),
#  ('dried red chile peppers', 103),
#  ('bow-tie pasta', 103),
#  ('whipped cream', 103),
#  ('marjoram', 103),
#  ('pecan halves', 102),
#  ('ground chicken', 102),
#  ('hazelnuts', 100),
#  ('dried porcini mushrooms', 100),
#  ('lemon grass', 100),
#  ('beans', 100),
#  ('masa harina', 100),
#  ('Mexican oregano', 100),
#  ('cottage cheese', 100),
#  ('sliced carrots', 100),
#  ('gruyere cheese', 99),
#  ('boiling potatoes', 99),
#  ('old bay seasoning', 98),
#  ('seasoned bread crumbs', 98),
#  ('sunflower oil', 97),
#  ('pears', 97),
#  ('broth', 97),
#  ('fresh mozzarella', 97),
#  ('greens', 96),
#  ('canned low sodium chicken broth', 96),
#  ('dill', 96),
#  ('nori', 96),
#  ('fresh shiitake mushrooms', 96),
#  ('dried currants', 95),
#  ('red kidney beans', 95),
#  ('grated orange peel', 95),
#  ('clams', 94),
#  ('adobo sauce', 94),
#  ('chicken drumsticks', 94),
#  ('cognac', 94),
#  ('orange bell pepper', 93),
#  ('leaves', 93),
#  ('rice vermicelli', 93),
#  ('whole wheat tortillas', 93),
#  ('blanched almonds', 93),
#  ('corn husks', 93),
#  ('vanilla ice cream', 93),
#  ('fat', 92),
#  ('prawns', 92),
#  ('cooked shrimp', 92),
#  ('fresh raspberries', 92),
#  ('firmly packed brown sugar', 92),
#  ('chicken pieces', 92),
#  ('clam juice', 92),
#  ('ripe olives', 92),
#  ('blackberries', 91),
#  ('orzo', 91),
#  ('fish', 91),
#  ('angel hair', 91),
#  ('stock', 90),
#  ('tamari soy sauce', 90),
#  ('fresh green bean', 90),
#  ('elbow macaroni', 90),
#  ('leg of lamb', 89),
#  ('jicama', 88),
#  ('rolls', 88),
#  ('herbs', 87),
#  ('amchur', 87),
#  ('lentils', 87),
#  ('quickcooking grits', 86),
#  ('baby bok choy', 86),
#  ('diced celery', 86),
#  ('green cardamom', 86),
#  ('tomatoes with juice', 86),
#  ('white cornmeal', 85),
#  ('asiago', 85),
#  ('galangal', 85),
#  ('mung bean sprouts', 85),
#  ('egg noodles', 85),
#  ('pearl onions', 85),
#  ('squid', 85),
#  ('tamarind paste', 84),
#  ('finely chopped fresh parsley', 84),
#  ('frozen whole kernel corn', 84),
#  ('vegetable oil spray', 84),
#  ('lamb shoulder', 84),
#  ('golden brown sugar', 83),
#  ('cream of chicken soup', 83),
#  ('panko', 83),
#  ('tomato juice', 83),
#  ('cream style corn', 83),
#  ('pineapple juice', 82),
#  ('pepper jack', 82),
#  ('caraway seeds', 82),
#  ('raspberries', 81),
#  ('mace', 81),
#  ('skim milk', 81),
#  ('marinade', 81),
#  ('sushi rice', 81),
#  ('agave nectar', 81),
#  ('serrano chilies', 81),
#  ('green cardamom pods', 80),
#  ('pizza sauce', 80),
#  ('sherry', 79),
#  ('canned black beans', 79),
#  ('pico de gallo', 79),
#  ('small red potato', 79),
#  ('grapeseed oil', 79),
#  ('crabmeat', 79),
#  ('white beans', 79),
#  ('boneless pork shoulder', 79),
#  ('table salt', 79),
#  ('fat skimmed chicken broth', 78),
#  ('ancho powder', 78),
#  ('fillets', 78),
#  ('low-fat buttermilk', 78),
#  ('sweet italian sausage', 78),
#  ('lime rind', 78),
#  ('rum', 77),
#  ('hominy', 77),
#  ('chicken bouillon', 77),
#  ('semi-sweet chocolate morsels', 77),
#  ('salted butter', 77),
#  ('fennel', 77),
#  ('coconut cream', 77),
#  ('fish fillets', 77),
#  ('white sesame seeds', 76),
#  ('reduced fat milk', 76),
#  ('whole cloves', 76),
#  ('chees fresh mozzarella', 76),
#  ('cauliflower florets', 75),
#  ('artichokes', 75),
#  ('canned tomatoes', 75),
#  ('cooked ham', 74),
#  ('instant yeast', 74),
#  ('sweetened coconut flakes', 74),
#  ('grated coconut', 74),
#  ('condensed milk', 74),
#  ('dried shrimp', 74),
#  ('vodka', 74),
#  ('skirt steak', 73),
#  ('ranch dressing', 73),
#  ('peeled tomatoes', 73),
#  ('miso paste', 73),
#  ('superfine sugar', 73),
#  ('fenugreek seeds', 73),
#  ('tilapia fillets', 73),
#  ('asafoetida', 73),
#  ('baby carrots', 72),
#  ('spinach leaves', 72),
#  ('prepared horseradish', 72),
#  ('egg substitute', 72),
#  ('lemon rind', 72),
#  ('pork loin', 71),
#  ('2% reduced-fat milk', 71),
#  ('refrigerated piecrusts', 71),
#  ('beef rib short', 71),
#  ('white miso', 71),
#  ('lower sodium chicken broth', 71),
#  ('red food coloring', 71),
#  ('cilantro stems', 71),
#  ('chunky salsa', 70),
#  ('fat free yogurt', 70),
#  ('corn flour', 70),
#  ('lemon slices', 70),
#  ('cachaca', 70),
#  ('poppy seeds', 70),
#  ('white hominy', 69),
#  ('rice paper', 69),
#  ('tomato ketchup', 69),
#  ('salad dressing', 69),
#  ('fresh curry leaves', 69),
#  ('coffee', 69),
#  ('masala', 69),
#  ('sirloin steak', 69),
#  ('curry', 68),
#  ('urad dal', 68),
#  ('red beans', 68),
#  ('parsnips', 68),
#  ('chorizo', 68),
#  ('soba noodles', 68),
#  ('coarse sea salt', 68),
#  ('portabello mushroom', 68),
#  ('Mexican cheese', 68),
#  ('hot pepper', 68),
#  ('chuck', 67),
#  ('chipotle peppers', 67),
#  ('grating cheese', 67),
#  ('pork butt', 67),
#  ('curds', 67),
#  ('phyllo dough', 67),
#  ('anchovy paste', 67),
#  ('bacon drippings', 66),
#  ('chuck roast', 66),
#  ('konbu', 66),
#  ('rotisserie chicken', 66),
#  ('plums', 66),
#  ('italian salad dressing', 66),
#  ('celery seed', 66),
#  ('chicken livers', 65),
#  ('creole mustard', 65),
#  ('red enchilada sauce', 65),
#  ('rigatoni', 65),
#  ('ground sirloin', 65),
#  ('beef tenderloin', 65),
#  ('halibut fillets', 65),
#  ('herbes de provence', 65),
#  ('steak', 64),
#  ('pistachios', 64),
#  ('coarse kosher salt', 64),
#  ('crimini mushrooms', 64),
#  ('dry roasted peanuts', 64),
#  ('preserved lemon', 63),
#  ('taco sauce', 63),
#  ('jumbo shrimp', 63),
#  ('corn syrup', 63),
#  ('dressing', 63),
#  ('mixed greens', 63),
#  ('shiitake mushroom caps', 63),
#  ('taco shells', 63),
#  ('dried sage', 63),
#  ('sweet pepper', 62),
#  ('low-fat sour cream', 62),
#  ('boneless pork loin', 62),
#  ('tahini', 62),
#  ('asparagus spears', 62),
#  ('condensed cream of chicken soup', 62),
#  ('short-grain rice', 62),
#  ('anise', 62),
#  ('lamb', 62),
#  ('cooking wine', 62),
#  ('smoked ham hocks', 62),
#  ('fresh marjoram', 62),
#  ('poultry seasoning', 62),
#  ('turkey', 62),
#  ('mashed potatoes', 62),
#  ('littleneck clams', 62),
#  ('orange liqueur', 61),
#  ('instant espresso powder', 61),
#  ('scallion greens', 61),
#  ('grated Gruyère cheese', 61),
#  ('skinless chicken breasts', 61),
#  ('salad', 61),
#  ('beef brisket', 61),
#  ('parmigiano-reggiano cheese', 61),
#  ('light mayonnaise', 61),
#  ('pumpkin', 61),
#  ('prunes', 61),
#  ('sweet corn', 61),
#  ('roasting chickens', 61),
#  ('manchego cheese', 60),
#  ('oysters', 60),
#  ('grated jack cheese', 60),
#  ('semolina', 60),
#  ('seasoned rice wine vinegar', 60),
#  ('liquid', 60),
#  ('parsley leaves', 60),
#  ('bird chile', 60),
#  ('cocoa powder', 60),
#  ('ramen noodles', 60),
#  ('white mushrooms', 60),
#  ('escarole', 60),
#  ('rotini', 60),
#  ('pie crust', 60),
#  ('rib', 59),
#  ('fenugreek leaves', 59),
#  ('potato starch', 59),
#  ('chinese cabbage', 59),
#  ('dipping sauces', 59),
#  ('sausage links', 59),
#  ('fish stock', 59),
#  ('semolina flour', 59),
#  ('chopped green chilies', 58),
#  ('unsalted dry roast peanuts', 58),
#  ('radicchio', 58),
#  ('spring roll wrappers', 58),
#  ('navel oranges', 58),
#  ('beaten eggs', 58),
#  ('dates', 58),
#  ('mango chutney', 58),
#  ('egg roll wrappers', 57),
#  ('lower sodium soy sauce', 57),
#  ('brown mustard seeds', 57),
#  ('fresh leav spinach', 57),
#  ('seaweed', 57),
#  ('roasted tomatoes', 57),
#  ('pepper flakes', 57),
#  ('wine', 57),
#  ('fresh oregano leaves', 57),
#  ('fresh pineapple', 56),
#  ('picante sauce', 56),
#  ('shrimp paste', 56),
#  ('salad oil', 56),
#  ('thick-cut bacon', 56),
#  ('swiss cheese', 55),
#  ('condensed cream of mushroom soup', 55),
#  ('cheese tortellini', 55),
#  ('savoy cabbage', 55),
#  ('light sour cream', 55),
#  ('pecorino cheese', 55),
#  ('biscuits', 55),
#  ('teriyaki sauce', 55),
#  ('chicken meat', 55),
#  ('firmly packed light brown sugar', 55),
#  ('smoked salmon', 55),
#  ('salmon', 55),
#  ('salami', 54),
#  ('hamburger buns', 54),
#  ('haricots verts', 54),
#  ('tea bags', 54),
#  ('sage', 54),
#  ('anise seed', 54),
#  ('guajillo chiles', 54),
#  ('Italian turkey sausage', 54),
#  ('whole milk ricotta cheese', 53),
#  ('boneless chicken thighs', 53),
#  ('pork loin chops', 53),
#  ('chutney', 53),
#  ('chips', 53),
#  ('japanese eggplants', 53),
#  ('reduced fat sharp cheddar cheese', 53),
#  ('fusilli', 53),
#  ('pepperoni', 52),
#  ('mustard powder', 52),
#  ('celery salt', 52),
#  ('fresh herbs', 52),
#  ('pork chops', 52),
#  ('sambal ulek', 52),
#  ('anchovies', 52),
#  ('deveined shrimp', 52),
#  ('dried cranberries', 51),
#  ('yellow peppers', 51),
#  ('extra sharp cheddar cheese', 51),
#  ('chickpea flour', 51),
#  ('puff pastry', 51),
#  ('kasuri methi', 51),
#  ('bottled clam juice', 51),
#  ('rubbed sage', 51),
#  ('mustard greens', 51),
#  ('edamame', 51),
#  ('malt vinegar', 51),
#  ('shredded parmesan cheese', 51),
#  ('clarified butter', 51),
#  ('apple juice', 51),
#  ('lime slices', 51),
#  ('nonfat yogurt', 51),
#  ('Anaheim chile', 51),
#  ('artichok heart marin', 51),
#  ('spanish chorizo', 51),
#  ('bread slices', 50),
#  ('great northern beans', 50),
#  ('turbinado', 50),
#  ('fruit', 50),
#  ('thai green curry paste', 50),
#  ('capsicum', 50),
#  ('gari', 50),
#  ('nonstick spray', 50),
#  ('granulated garlic', 50),
#  ('California bay leaves', 50),
#  ('steamed rice', 50),
#  ('crushed ice', 50),
#  ('chicken bouillon granules', 50),
#  ('wild mushrooms', 50),
#  ('plain low-fat yogurt', 50),
#  ('ground almonds', 50),
#  ('sourdough bread', 50),
#  ('lobster', 50),
#  ('seedless cucumber', 50),
#  ('softened butter', 49),
#  ('duck', 49),
#  ('plain whole-milk yogurt', 49),
#  ('green bell pepper, slice', 49),
#  ...]

# %%
# list of 5 words to test (to do calculations on)
test_words = ['fresh basil', 'cilantro', 'kalamata olives', 'black beans', 'garam masala']

# %%
# code taken from:  https://www.kaggle.com/code/ccorbi/word2vec-with-ingredients/notebook (word2vec with ingredients)
symbols = list()

for recipe in train_recipes:
    for ingredient in recipe['ingredients']:
        if re.match("\(|@|\$\?", ingredient.lower()):
            symbols.append(ingredient)
len(symbols)
counts_symbols = collections.Counter(symbols)
counts_symbols.most_common(20)
# Out:
# [('(    oz.) tomato sauce', 11),
#  ('(   oz.) tomato paste', 9),
#  ('(14.5 oz.) diced tomatoes', 3),
#  ('(15 oz.) refried beans', 3),
#  ('(10 oz.) frozen chopped spinach', 3),
#  ('(10 oz.) frozen chopped spinach, thawed and squeezed dry', 2),
#  ('(14 oz.) sweetened condensed milk', 2)]

# %%
# code taken from:  https://www.kaggle.com/code/ccorbi/word2vec-with-ingredients/notebook (word2vec with ingredients)
sentences = list()
# one hot ingredients


for recipt in train_recipes:
    clean_recipt = list()
    for ingredient in recipt['ingredients']:
        # remove this description from the ingredients
        # minimal preprocessing
        ingredient =  re.sub(r'\(.*oz.\)|crushed|crumbles|ground|minced|powder|chopped|sliced',
                             '',
                             ingredient)
        clean_recipt.append(ingredient.strip())
    sentences.append(clean_recipt)

len(sentences)
# Out:
# 39774

# %% [markdown]
# # Word2Vec Model 1

# %%
# code taken from:  https://www.kaggle.com/code/ccorbi/word2vec-with-ingredients/notebook (word2vec with ingredients)

# Set values for NN parameters
num_features = 300    # Word vector dimensionality
min_word_count = 3    # 50% of the corpus
num_workers = 4       # Number of CPUs
context = 10          # window size
downsampling = 1e-3   # threshold for configuring which
                      # higher-frequency words are randomly downsampled

# Initialize and train the model
model = word2vec.Word2Vec(workers=num_workers, \
            vector_size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling)

# %%
# code taken from: https://www.kaggle.com/code/pierremegret/gensim-word2vec-tutorial (gensim word2vec tutorial)
t = time()

model.build_vocab(sentences, progress_per=10000)

print('Time to build vocab:', time() - t)
# Out:
# Time to build vocab: 0.17156410217285156

# %%
# code taken from: https://www.kaggle.com/code/pierremegret/gensim-word2vec-tutorial (gensim word2vec tutorial)
t = time()

model.train(sentences, total_examples=model.corpus_count, epochs=10, report_delay=1)

print('Time to train the model:', time() - t)
# Out:
# Time to train the model: 9.646828889846802

# %% [markdown]
# ## Top-1, Top-5, Top-10 for model 1

# %%
topWordsCalculations(model, test_words)
# Out:
# word= fresh basil
# output: [('fresh basil leaves', 0.7428125143051147), ('basil leaves', 0.7322972416877747), ('chees fresh mozzarella', 0.6709271669387817), ('penne', 0.6659830808639526), ('Italian turkey sausage', 0.6659452319145203), ('olive oil flavored cooking spray', 0.647891104221344), ('bow-tie pasta', 0.6407570838928223), ('pesto', 0.6385067701339722), ('yellow squash', 0.6304804086685181), ('spinach leaves', 0.6240914463996887)]
# top-1 average: 0.7428125143051147
# top-5 average: 0.6955930471420289
# top-10 average: 0.6659692049026489
#
#
# word= cilantro
# output: [('fresh cilantro', 0.8856534361839294), ('cilantro leaves', 0.858186662197113), ('cilantro fresh', 0.7167872786521912), ('fresh coriander', 0.6562798023223877), ('cilantro stems', 0.6503143310546875), ('sweet corn', 0.5807778239250183), ('serrano peppers', 0.5773773789405823), ('chile', 0.5482127666473389), ('hot chili', 0.5370160937309265), ('Mexican oregano', 0.5146968960762024)]
# top-1 average: 0.8856534361839294
# top-5 average: 0.7534443020820618
# top-10 average: 0.6525302469730377
#
#
# word= kalamata olives
# output: [('extra fine granulated sugar', 0.9092204570770264), ('grass-fed butter', 0.9065915942192078), ('ouzo', 0.885994553565979), ('globe eggplant', 0.8858441114425659), ('assorted fresh vegetables', 0.8842945098876953), ('pita pockets', 0.878463625907898), ('branzino', 0.8783990144729614), ('red russian kale', 0.8746089339256287), ('enriched white rice', 0.8723511099815369), ('loaves', 0.8691681623458862)]
# top-1 average: 0.9092204570770264
# top-5 average: 0.8943890452384948
# top-10 average: 0.8844936072826386
#
#
# word= black beans
# output: [('canned black beans', 0.8852002024650574), ('pinto beans', 0.838304877281189), ('frozen corn', 0.8266984820365906), ('poblano peppers', 0.8193145394325256), ('whole wheat tortillas', 0.808560848236084), ('chipotle peppers', 0.8071742057800293), ('guacamole', 0.8059782385826111), ('chipotle chile pepper', 0.7915951013565063), ('tortilla chips', 0.7866435647010803), ('tortillas', 0.7674216032028198)]
# top-1 average: 0.8852002024650574
# top-5 average: 0.8356157898902893
# top-10 average: 0.8136891663074494
#
#
# word= garam masala
# output: [('tumeric', 0.8292970657348633), ('coriander', 0.8267992734909058), ('masala', 0.807604968547821), ('turmeric', 0.8073639273643494), ('basmati rice', 0.8043537139892578), ('yoghurt', 0.7899531722068787), ('whole milk yoghurt', 0.7791794538497925), ('fenugreek leaves', 0.7783532738685608), ('fenugreek', 0.7642073035240173), ('red lentils', 0.7571282386779785)]
# top-1 average: 0.8292970657348633
# top-5 average: 0.8150837898254395
# top-10 average: 0.7944240391254425

# %%
model.wv.most_similar(['eggs', 'milk', 'vanilla extract'])
# Out:
# [('evaporated milk', 0.8159870505332947),
#  ('pastry', 0.7985823750495911),
#  ('softened butter', 0.7826281189918518),
#  ('beaten eggs', 0.780570924282074),
#  ('melted butter', 0.772914707660675),
#  ('semi-sweet chocolate morsels', 0.7638320922851562),
#  ('shortening', 0.7602747082710266),
#  ('single crust pie', 0.7598553895950317),
#  ('pie crust', 0.7565968632698059),
#  ('whole wheat pastry flour', 0.7527552247047424)]

# %% [markdown]
# # Word2Vec Model 2 - Decreased Window Size by 1/2

# %%
# code taken from:  https://www.kaggle.com/code/ccorbi/word2vec-with-ingredients/notebook (word2vec with ingredients)

# Set values for NN parameters
num_features = 300    # Word vector dimensionality
min_word_count = 3    # 50% of the corpus
num_workers = 4       # Number of CPUs
context = 5          # window size
downsampling = 1e-3   # threshold for configuring which
                      # higher-frequency words are randomly downsampled

# Initialize and train the model
model2 = word2vec.Word2Vec(workers=num_workers, \
            vector_size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling)

# %%
# code taken from: https://www.kaggle.com/code/pierremegret/gensim-word2vec-tutorial (gensim word2vec tutorial)
t = time()

model2.build_vocab(sentences, progress_per=10000)

print('Time to build vocab:', time() - t)
# Out:
# Time to build vocab: 0.23670148849487305

# %%
# code taken from: https://www.kaggle.com/code/pierremegret/gensim-word2vec-tutorial (gensim word2vec tutorial)
t = time()

model2.train(sentences, total_examples=model2.corpus_count, epochs=10, report_delay=1)

print('Time to train the model:', time() - t)
# Out:
# Time to train the model: 7.734004497528076

# %% [markdown]
# ## Top-1, Top-5, Top-10 for model 2

# %%
topWordsCalculations(model2, test_words)
# Out:
# word= fresh basil
# output: [('fresh basil leaves', 0.7621052861213684), ('basil leaves', 0.7479035258293152), ('linguine', 0.7066890001296997), ('bow-tie pasta', 0.7018566131591797), ('chees fresh mozzarella', 0.6827179789543152), ('penne', 0.6805809140205383), ('pesto', 0.662975549697876), ('yellow squash', 0.6602261066436768), ('spinach leaves', 0.6521127820014954), ('fusilli', 0.6481409668922424)]
# top-1 average: 0.7621052861213684
# top-5 average: 0.7202544808387756
# top-10 average: 0.6905308723449707
#
#
# word= cilantro
# output: [('fresh cilantro', 0.8399322032928467), ('cilantro leaves', 0.8198192715644836), ('cilantro fresh', 0.6991016268730164), ('chile', 0.6756662130355835), ('serrano peppers', 0.6597104668617249), ('cooked brown rice', 0.6166772842407227), ('cilantro stems', 0.606759786605835), ('fresh coriander', 0.6028186082839966), ('hot chili', 0.6027405261993408), ('sweet corn', 0.5893930792808533)]
# top-1 average: 0.8399322032928467
# top-5 average: 0.738845956325531
# top-10 average: 0.6712619066238403
#
#
# word= kalamata olives
# output: [('tuna packed in water', 0.9445316195487976), ('flat anchovy', 0.9378742575645447), ('hot cherry pepper', 0.92526775598526), ('pita chips', 0.9172925353050232), ('country loaf', 0.9148755073547363), ('pita rounds', 0.9143105149269104), ('peperoncini', 0.9113659858703613), ('balsamic vinaigrette', 0.9021040201187134), ('tapenade', 0.8968738913536072), ('bocconcini', 0.8945508003234863)]
# top-1 average: 0.9445316195487976
# top-5 average: 0.9279683351516723
# top-10 average: 0.9159046888351441
#
#
# word= black beans
# output: [('canned black beans', 0.9246068000793457), ('poblano peppers', 0.8699742555618286), ('salsa verde', 0.8507108092308044), ('whole wheat tortillas', 0.8484592437744141), ('chipotle chile pepper', 0.8398043513298035), ('guacamole', 0.8397717475891113), ('Mexican cheese blend', 0.8382490277290344), ('pinto beans', 0.8378378748893738), ('pepper jack', 0.8324622511863708), ('taco shells', 0.8302130699157715)]
# top-1 average: 0.9246068000793457
# top-5 average: 0.8667110919952392
# top-10 average: 0.8512089431285859
#
#
# word= garam masala
# output: [('masala', 0.8287578821182251), ('coriander', 0.8212893009185791), ('fenugreek leaves', 0.8117449879646301), ('basmati rice', 0.8093999624252319), ('fenugreek', 0.8081806898117065), ('tumeric', 0.8081257939338684), ('red lentils', 0.8047021627426147), ('turmeric', 0.8042529225349426), ('yoghurt', 0.8033658266067505), ('fenugreek seeds', 0.7943703532218933)]
# top-1 average: 0.8287578821182251
# top-5 average: 0.8158745646476746
# top-10 average: 0.8094189882278442

# %%
model2.wv.most_similar(['eggs', 'milk', 'vanilla extract'])
# Out:
# [('low-fat milk', 0.8713571429252625),
#  ('evaporated milk', 0.8594532012939453),
#  ('melted butter', 0.8495365381240845),
#  ('softened butter', 0.8274590373039246),
#  ('pastry', 0.8174067735671997),
#  ('shortening', 0.8144609332084656),
#  ('single crust pie', 0.7883224487304688),
#  ('medium eggs', 0.7871817350387573),
#  ('lemon extract', 0.7867909669876099),
#  ('golden syrup', 0.7859845757484436)]

# %% [markdown]
# # Word2Vec Model 3 - Added learning rate of 0.005

# %%
# code taken from:  https://www.kaggle.com/code/ccorbi/word2vec-with-ingredients/notebook (word2vec with ingredients)

# Set values for NN parameters
num_features = 300    # Word vector dimensionality
min_word_count = 3    # 50% of the corpus
num_workers = 4       # Number of CPUs
context = 10          # window size
downsampling = 1e-3   # threshold for configuring which
                      # higher-frequency words are randomly downsampled

# Initialize and train the model
model3 = word2vec.Word2Vec(workers=num_workers, \
            vector_size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling, alpha=0.005)

# %%
# code taken from: https://www.kaggle.com/code/pierremegret/gensim-word2vec-tutorial (gensim word2vec tutorial)
t = time()

model3.build_vocab(sentences, progress_per=10000)

print('Time to build vocab:', time() - t)
# Out:
# Time to build vocab: 0.23292899131774902

# %%
# code taken from: https://www.kaggle.com/code/pierremegret/gensim-word2vec-tutorial (gensim word2vec tutorial)
t = time()

model3.train(sentences, total_examples=model3.corpus_count, epochs=10, report_delay=1)

print('Time to train the model:', time() - t)
# Out:
# Time to train the model: 10.170792818069458

# %% [markdown]
# ## Top-1, Top-5, Top-10 for model 3

# %%
topWordsCalculations(model3, test_words)
# Out:
# word= fresh basil
# output: [('balsamic vinegar', 0.9886016249656677), ('fresh basil leaves', 0.9833713173866272), ('freshly  pepper', 0.9761232733726501), ('linguine', 0.9750982522964478), ('capers', 0.9738101959228516), ('pitted kalamata olives', 0.9735633730888367), ('fresh oregano', 0.9724856615066528), ('spaghetti', 0.9699956774711609), ('extra-virgin olive oil', 0.9664415121078491), ('fat free less sodium chicken broth', 0.966299295425415)]
# top-1 average: 0.9886016249656677
# top-5 average: 0.9794009327888489
# top-10 average: 0.9745790183544158
#
#
# word= cilantro
# output: [('fresh cilantro', 0.9871524572372437), ('lime', 0.9787974953651428), ('lime juice', 0.9727945327758789), ('lime wedges', 0.9701160788536072), ('cilantro fresh', 0.9577324986457825), ('cilantro leaves', 0.954762876033783), ('chicken breasts', 0.9540164470672607), ('jalapeno chilies', 0.9519700407981873), ('white onion', 0.9512802362442017), ('chipotle paste', 0.9457230567932129)]
# top-1 average: 0.9871524572372437
# top-5 average: 0.973318612575531
# top-10 average: 0.96243457198143
#
#
# word= kalamata olives
# output: [('dry red wine', 0.9194468259811401), ('dried rosemary', 0.9148616194725037), ('parsley sprigs', 0.9142893552780151), ('low salt chicken broth', 0.9141350388526917), ('italian plum tomatoes', 0.9134431481361389), ('red wine', 0.9131529927253723), ('fennel bulb', 0.9128929972648621), ('orzo pasta', 0.9115782380104065), ('white wine', 0.9105476140975952), ('ditalini', 0.9105328321456909)]
# top-1 average: 0.9194468259811401
# top-5 average: 0.9152351975440979
# top-10 average: 0.9134880661964416
#
#
# word= black beans
# output: [('corn tortillas', 0.9929153323173523), ('tortilla chips', 0.9928678274154663), ('guacamole', 0.9899529218673706), ('cotija', 0.9861535429954529), ('corn', 0.9858227372169495), ('flour tortillas', 0.9850752949714661), ('salsa', 0.984722912311554), ('enchilada sauce', 0.9845128655433655), ('green chile', 0.984503984451294), ('tortillas', 0.9817508459091187)]
# top-1 average: 0.9929153323173523
# top-5 average: 0.9895424723625184
# top-10 average: 0.9868278264999389
#
#
# word= garam masala
# output: [('tumeric', 0.9976426362991333), ('turmeric', 0.9975494742393494), ('coriander', 0.996055543422699), ('cumin seed', 0.9916380643844604), ('basmati rice', 0.976142942905426), ('clove', 0.9719006419181824), ('mustard seeds', 0.9671228528022766), ('coriander seeds', 0.9644714593887329), ('garlic paste', 0.964306652545929), ('green chilies', 0.9626431465148926)]
# top-1 average: 0.9976426362991333
# top-5 average: 0.9918057322502136
# top-10 average: 0.9789473414421082

# %%
model3.wv.most_similar(['eggs', 'milk', 'vanilla extract'])
# Out:
# [('buttermilk', 0.9875501990318298),
#  ('unbaked pie crusts', 0.982410192489624),
#  ('baking', 0.9808518886566162),
#  ('shortening', 0.980090320110321),
#  ('melted butter', 0.9729699492454529),
#  ('anise extract', 0.9702609181404114),
#  ('cornmeal', 0.9696202278137207),
#  ('evaporated milk', 0.9695850610733032),
#  ('farmer cheese', 0.9665543437004089),
#  ('self rising flour', 0.9648932218551636)]

# %% [markdown]
# # Word2Vec Model 4 - Decreased Window Size (window = 5), Learning Rate Added (lr = 0.005)

# %%
# code taken from:  https://www.kaggle.com/code/ccorbi/word2vec-with-ingredients/notebook (word2vec with ingredients)

# Set values for NN parameters
num_features = 300    # Word vector dimensionality
min_word_count = 3    # 50% of the corpus
num_workers = 4       # Number of CPUs
context = 5          # window size
downsampling = 1e-3   # threshold for configuring which
                      # higher-frequency words are randomly downsampled

# Initialize and train the model
model4 = word2vec.Word2Vec(workers=num_workers, \
            vector_size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling, alpha=0.005)

# %%
# code taken from: https://www.kaggle.com/code/pierremegret/gensim-word2vec-tutorial (gensim word2vec tutorial)
t = time()

model4.build_vocab(sentences, progress_per=10000)

print('Time to build vocab:', time() - t)
# Out:
# Time to build vocab: 0.22496700286865234

# %%
# code taken from: https://www.kaggle.com/code/pierremegret/gensim-word2vec-tutorial (gensim word2vec tutorial)
t = time()

model4.train(sentences, total_examples=model4.corpus_count, epochs=10, report_delay=1)

print('Time to train the model:', time() - t)
# Out:
# Time to train the model: 9.091677188873291

# %% [markdown]
# ## Top-1, Top-5, Top-10 for model 4

# %%
topWordsCalculations(model4, test_words)
# Out:
# word= fresh basil
# output: [('balsamic vinegar', 0.9876619577407837), ('extra-virgin olive oil', 0.9849947094917297), ('capers', 0.9828872680664062), ('fresh basil leaves', 0.979954719543457), ('fresh oregano', 0.9786477088928223), ('linguine', 0.9735621213912964), ('arborio rice', 0.9734840393066406), ('spaghetti', 0.9728142023086548), ('flat leaf parsley', 0.9714289307594299), ('freshly  pepper', 0.9708184003829956)]
# top-1 average: 0.9876619577407837
# top-5 average: 0.9828292727470398
# top-10 average: 0.9776254057884216
#
#
# word= cilantro
# output: [('fresh cilantro', 0.9888460040092468), ('lime', 0.9884642362594604), ('lime juice', 0.9845849275588989), ('lime wedges', 0.9755030870437622), ('cilantro fresh', 0.9707152247428894), ('chicken breasts', 0.9647049903869629), ('jalapeno chilies', 0.9620205163955688), ('cilantro leaves', 0.9571397304534912), ('white onion', 0.9512550234794617), ('boneless skinless chicken breasts', 0.9496047496795654)]
# top-1 average: 0.9888460040092468
# top-5 average: 0.9816226959228516
# top-10 average: 0.9692838490009308
#
#
# word= kalamata olives
# output: [('pasta', 0.9271238446235657), ('penne pasta', 0.9267390370368958), ('cannellini beans', 0.9247123003005981), ('italian sausage', 0.9239885210990906), ('sweet italian sausage', 0.9229277968406677), ('kalamata', 0.9219010472297668), ('spaghetti', 0.9211446642875671), ('italian seasoning', 0.9210634827613831), ('part-skim mozzarella cheese', 0.9210060238838196), ('finely  onion', 0.9209407567977905)]
# top-1 average: 0.9271238446235657
# top-5 average: 0.9250982999801636
# top-10 average: 0.9231547474861145
#
#
# word= black beans
# output: [('corn tortillas', 0.9968032240867615), ('flour tortillas', 0.9908587336540222), ('tortilla chips', 0.9901202321052551), ('salsa', 0.9884030818939209), ('jalapeno chilies', 0.9873879551887512), ('avocado', 0.9855659008026123), ('enchilada sauce', 0.9847285151481628), ('taco seasoning', 0.984626293182373), ('refried beans', 0.984143078327179), ('shredded Monterey Jack cheese', 0.9828854203224182)]
# top-1 average: 0.9968032240867615
# top-5 average: 0.9907146453857422
# top-10 average: 0.9875522434711457
#
#
# word= garam masala
# output: [('coriander', 0.9978469014167786), ('turmeric', 0.9975991249084473), ('tumeric', 0.9956970810890198), ('cumin seed', 0.9944854378700256), ('green chilies', 0.973973274230957), ('garlic paste', 0.9645842909812927), ('clove', 0.9640976786613464), ('mustard seeds', 0.9541863799095154), ('curry leaves', 0.9514783620834351), ('coriander seeds', 0.946915864944458)]
# top-1 average: 0.9978469014167786
# top-5 average: 0.9919203639030456
# top-10 average: 0.9740864396095276

# %%
model4.wv.most_similar(['eggs', 'milk', 'vanilla extract'])
# Out:
# [('buttermilk', 0.9928349256515503),
#  ('shortening', 0.9897841811180115),
#  ('baking', 0.9897537231445312),
#  ('cornmeal', 0.9829892516136169),
#  ('pecans', 0.9821597933769226),
#  ('baking soda', 0.9802330136299133),
#  ('vanilla', 0.9801535606384277),
#  ('melted butter', 0.9798804521560669),
#  ('white cornmeal', 0.9791784882545471),
#  ('confectioners sugar', 0.9790623188018799)]
